# %% [markdown]
# # <span style="color:gray">Zestimate and Actual Sale Price Difference</span>

# %% [markdown]
#  ## <span style="color:black">1. Define</span>
#  Problem -
#  >Predict the log-error between their Zestimate and the actual sale price, given all the features of a home.
#  >
#              log-error=log(Zestimate)−log(SalePrice)
#  >
#  > Predict the logerror for the months in Fall 2017
#
#  What we have -
#  >a full list of real estate properties in three counties (Los Angeles, Orange and Ventura, California) data in 2016.
#  >The train data has all the transactions before October 15, 2016, plus some of the transactions after October 15, 2016.
#  >The test data in the public leaderboard has the rest of the transactions between October 15 and December 31, 2016.
#  >4 Categorical/Qualitative - companyId, jobType, degree, major, industry
#  >2 Numeric/Quantitative - yearsExperience, milesFromMetropolis
#
#  Type of Algorithm -
#  >

# %% [markdown]
#  ## <span style="color:black">2. Discover</span>

# %% [markdown]
# ### <span style="color:black">2.1. Import Libraries</span>

# %%
# %%capture
! pip install seaborn
#import initial libraries
import pandas as pd
import numpy as np
from numpy import NaN
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
pd.set_option('display.max_rows', 70)
pd.set_option('display.max_columns', 60)
#pd.set_option('display.width', 100)

# %%
import os
for dirname, _, filenames in os.walk('C:/Users/Manohar/Documents/DataScience/zillow/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:/Users/Manohar/Documents/DataScience/zillow/properties_2016.csv
# C:/Users/Manohar/Documents/DataScience/zillow/properties_2017.csv
# C:/Users/Manohar/Documents/DataScience/zillow/sample_submission.csv
# C:/Users/Manohar/Documents/DataScience/zillow/train_2016_v2.csv
# C:/Users/Manohar/Documents/DataScience/zillow/train_2017.csv

# %%
prop16 = pd.read_csv("C:/Users/Manohar/Documents/DataScience/zillow/properties_2016.csv")
#prop17 = pd.read_csv("C:/Users/Manohar/Documents/DataScience/zillow/properties_2017.csv")
smplsub = pd.read_csv("C:/Users/Manohar/Documents/DataScience/zillow/sample_submission.csv")
train16 = pd.read_csv("C:/Users/Manohar/Documents/DataScience/zillow/train_2016_v2.csv", parse_dates=["transactiondate"])
#train17 = pd.read_csv("C:/Users/Manohar/Documents/DataScience/zillow/train_2017.csv", parse_dates=["transactiondate"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (22,32,34,49,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train16 = pd.read_csv("C:/Users/Manohar/Documents/DataScience/zillow/train_2016_v2.csv", parse_dates=["transactiondate"])

# %%
prop16.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# 0                NaN         NaN                       NaN
# 1                NaN         NaN                       NaN
# 2                NaN         NaN                       NaN
# 3                NaN         NaN                       NaN
# 4                NaN         NaN                       NaN
#
#    calculatedfinishedsquarefeet  finishedsquarefeet12  finishedsquarefeet13  \
# 0                           NaN                   NaN                   NaN
# 1                           NaN                   NaN                   NaN
# 2                       73026.0                   NaN                   NaN
# 3                        5068.0                   NaN                   NaN
# 4                        1776.0                   NaN                   NaN
#
#    finishedsquarefeet15  finishedsquarefeet50  finishedsquarefeet6    fips  \
# 0                   NaN                   NaN                  NaN  6037.0
# 1                   NaN                   NaN                  NaN  6037.0
# 2               73026.0                   NaN                  NaN  6037.0
# 3                5068.0                   NaN                  NaN  6037.0
# 4                1776.0                   NaN                  NaN  6037.0
#
#    fireplacecnt  fullbathcnt  garagecarcnt  garagetotalsqft hashottuborspa  \
# 0           NaN          NaN           NaN              NaN            NaN
# 1           NaN          NaN           NaN              NaN            NaN
# 2           NaN          NaN           NaN              NaN            NaN
# 3           NaN          NaN           NaN              NaN            NaN
# 4           NaN          NaN           NaN              NaN            NaN
#
#    heatingorsystemtypeid    latitude    longitude  lotsizesquarefeet  poolcnt  \
# 0                    NaN  34144442.0 -118654084.0            85768.0      NaN
# 1                    NaN  34140430.0 -118625364.0             4083.0      NaN
# 2                    NaN  33989359.0 -118394633.0            63085.0      NaN
# 3                    NaN  34148863.0 -118437206.0             7521.0      NaN
# 4                    NaN  34194168.0 -118385816.0             8512.0      NaN
#
#    poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# 0          NaN           NaN          NaN          NaN
# 1          NaN           NaN          NaN          NaN
# 2          NaN           NaN          NaN          NaN
# 3          NaN           NaN          NaN          NaN
# 4          NaN           NaN          NaN          NaN
#
#   propertycountylandusecode  propertylandusetypeid propertyzoningdesc  \
# 0                      010D                  269.0                NaN
# 1                      0109                  261.0             LCA11*
# 2                      1200                   47.0               LAC2
# 3                      1200                   47.0               LAC2
# 4                      1210                   31.0               LAM1
#
#    rawcensustractandblock  regionidcity  regionidcounty  regionidneighborhood  \
# 0            6.037800e+07       37688.0          3101.0                   NaN
# 1            6.037800e+07       37688.0          3101.0                   NaN
# 2            6.037703e+07       51617.0          3101.0                   NaN
# 3            6.037141e+07       12447.0          3101.0               27080.0
# 4            6.037123e+07       12447.0          3101.0               46795.0
#
#    regionidzip  roomcnt  storytypeid  threequarterbathnbr  \
# 0      96337.0      0.0          NaN                  NaN
# 1      96337.0      0.0          NaN                  NaN
# 2      96095.0      0.0          NaN                  NaN
# 3      96424.0      0.0          NaN                  NaN
# 4      96450.0      0.0          NaN                  NaN
#
#    typeconstructiontypeid  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 0                     NaN      NaN                 NaN                 NaN
# 1                     NaN      NaN                 NaN                 NaN
# 2                     NaN      2.0                 NaN                 NaN
# 3                     NaN      NaN                 NaN                 NaN
# 4                     NaN      1.0                 NaN                 NaN
#
#    yearbuilt  numberofstories fireplaceflag  structuretaxvaluedollarcnt  \
# 0        NaN              NaN           NaN                         NaN
# 1        NaN              NaN           NaN                         NaN
# 2        NaN              NaN           NaN                    650756.0
# 3     1948.0              1.0           NaN                    571346.0
# 4     1947.0              NaN           NaN                    193796.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0                9.0          2015.0                    9.0        NaN
# 1            27516.0          2015.0                27516.0        NaN
# 2          1413387.0          2015.0               762631.0   20800.37
# 3          1156834.0          2015.0               585488.0   14557.57
# 4           433491.0          2015.0               239695.0    5725.17
#
#   taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 0                NaN                 NaN                  NaN
# 1                NaN                 NaN                  NaN
# 2                NaN                 NaN                  NaN
# 3                NaN                 NaN                  NaN
# 4                NaN                 NaN                  NaN

# %%
def num_after_point(x):
    s = str(x)
    if not '.' in s:
        return 0
    return len(s) - s.index('.') - 1

# %%
def full_info(df):
    df_column=[]
    df_dtype=[]
    df_null=[]
    df_nullc=[]
    df_mean=[]
    df_median=[]
    df_std=[]
    df_min=[]
    df_max=[]
    df_uniq=[]
    for col in df.columns: 
        df_column.append( col)
        df_dtype.append( df[col].dtype)
        df_null.append( round(100 * df[col].isnull().sum(axis=0)/len(df[col]),2))
        df_nullc.append( df[col].isnull().sum(axis=0))
        df_uniq.append( df[col].nunique()) if df[col].dtype == 'object' else df_uniq.append( NaN)
        df_mean.append(  '{0:.2f}'.format(df[col].mean())) if df[col].dtype == 'int64' or df[col].dtype == 'float64' else df_mean.append( NaN)
        df_median.append( '{0:.2f}'.format(df[col].median())) if df[col].dtype == 'int64' or df[col].dtype == 'float64' else df_median.append( NaN)
        df_std.append( '{0:.2f}'.format(df[col].std())) if df[col].dtype == 'int64' or df[col].dtype == 'float64' else df_std.append( NaN)
        df_max.append( '{0:.2f}'.format(df[col].max())) if df[col].dtype == 'int64' or df[col].dtype == 'float64' else df_max.append( NaN)
        df_min.append( '{0:.2f}'.format(df[col].min())) if df[col].dtype == 'int64' or df[col].dtype == 'float64' else df_min.append( NaN)
    return pd.DataFrame(data = {'col_name': df_column, 'col_type': df_dtype, 'Null_Count': df_nullc, 'Null_Count%': df_null,  'Min': df_min, 'Max': df_max, 'Mean': df_mean, 'Med': df_median, 'Std': df_std, 'UniqCnt': df_uniq})

# %%
full_info(prop16)
# Out:
#                         col_name col_type  Null_Count  Null_Count%  \
# 0                       parcelid    int64           0         0.00
# 1          airconditioningtypeid  float64     2173698        72.82
# 2       architecturalstyletypeid  float64     2979156        99.80
# 3                   basementsqft  float64     2983589        99.95
# 4                    bathroomcnt  float64       11462         0.38
# 5                     bedroomcnt  float64       11450         0.38
# 6            buildingclasstypeid  float64     2972588        99.58
# 7          buildingqualitytypeid  float64     1046729        35.06
# 8              calculatedbathnbr  float64      128912         4.32
# 9                     decktypeid  float64     2968121        99.43
# 10      finishedfloor1squarefeet  float64     2782500        93.21
# 11  calculatedfinishedsquarefeet  float64       55565         1.86
# 12          finishedsquarefeet12  float64      276033         9.25
# 13          finishedsquarefeet13  float64     2977545        99.74
# 14          finishedsquarefeet15  float64     2794419        93.61
# 15          finishedsquarefeet50  float64     2782500        93.21
# 16           finishedsquarefeet6  float64     2963216        99.26
# 17                          fips  float64       11437         0.38
# 18                  fireplacecnt  float64     2672580        89.53
# 19                   fullbathcnt  float64      128912         4.32
# 20                  garagecarcnt  float64     2101950        70.41
# 21               garagetotalsqft  float64     2101950        70.41
# 22                hashottuborspa   object     2916203        97.69
# 23         heatingorsystemtypeid  float64     1178816        39.49
# 24                      latitude  float64       11437         0.38
# 25                     longitude  float64       11437         0.38
# 26             lotsizesquarefeet  float64      276099         9.25
# 27                       poolcnt  float64     2467683        82.66
# 28                   poolsizesum  float64     2957257        99.06
# 29                  pooltypeid10  float64     2948278        98.76
# 30                   pooltypeid2  float64     2953142        98.93
# 31                   pooltypeid7  float64     2499758        83.74
# 32     propertycountylandusecode   object       12277         0.41
# 33         propertylandusetypeid  float64       11437         0.38
# 34            propertyzoningdesc   object     1006588        33.72
# 35        rawcensustractandblock  float64       11437         0.38
# 36                  regionidcity  float64       62845         2.11
# 37                regionidcounty  float64       11437         0.38
# 38          regionidneighborhood  float64     1828815        61.26
# 39                   regionidzip  float64       13980         0.47
# 40                       roomcnt  float64       11475         0.38
# 41                   storytypeid  float64     2983593        99.95
# 42           threequarterbathnbr  float64     2673586        89.56
# 43        typeconstructiontypeid  float64     2978470        99.77
# 44                       unitcnt  float64     1007727        33.76
# 45            yardbuildingsqft17  float64     2904862        97.31
# 46            yardbuildingsqft26  float64     2982570        99.91
# 47                     yearbuilt  float64       59928         2.01
# 48               numberofstories  float64     2303148        77.15
# 49                 fireplaceflag   object     2980054        99.83
# 50    structuretaxvaluedollarcnt  float64       54982         1.84
# 51             taxvaluedollarcnt  float64       42550         1.43
# 52                assessmentyear  float64       11439         0.38
# 53         landtaxvaluedollarcnt  float64       67733         2.27
# 54                     taxamount  float64       31250         1.05
# 55            taxdelinquencyflag   object     2928755        98.11
# 56            taxdelinquencyyear  float64     2928753        98.11
# 57           censustractandblock  float64       75126         2.52
#
#               Min                 Max               Mean                Med  \
# 0     10711725.00        169601949.00        13325858.36        12545094.00
# 1            1.00               13.00               1.93               1.00
# 2            2.00               27.00               7.20               7.00
# 3           20.00             8516.00             646.88             534.00
# 4            0.00               20.00               2.21               2.00
# 5            0.00               20.00               3.09               3.00
# 6            1.00                5.00               3.73               4.00
# 7            1.00               12.00               5.78               7.00
# 8            1.00               20.00               2.30               2.00
# 9           66.00               66.00              66.00              66.00
# 10           3.00            31303.00            1380.63            1283.00
# 11           1.00           952576.00            1827.16            1572.00
# 12           1.00           290345.00            1760.00            1539.00
# 13         120.00             2688.00            1178.90            1296.00
# 14         112.00           820242.00            2739.19            2172.00
# 15           3.00            31303.00            1388.94            1284.00
# 16         117.00           952576.00            2414.34            1992.00
# 17        6037.00             6111.00            6048.03            6037.00
# 18           1.00                9.00               1.17               1.00
# 19           1.00               20.00               2.24               2.00
# 20           0.00               25.00               1.82               2.00
# 21           0.00             7749.00             383.77             441.00
# 22            NaN                 NaN                NaN                NaN
# 23           1.00               24.00               4.01               2.00
# 24    33324388.00         34819650.00        34001468.65        34008249.00
# 25  -119475780.00       -117554316.00      -118201934.16      -118172540.50
# 26         100.00        328263808.00           22822.81            7000.00
# 27           1.00                1.00               1.00               1.00
# 28          19.00            17410.00             519.71             495.00
# 29           1.00                1.00               1.00               1.00
# 30           1.00                1.00               1.00               1.00
# 31           1.00                1.00               1.00               1.00
# 32            NaN                 NaN                NaN                NaN
# 33          31.00              275.00             260.05             261.00
# 34            NaN                 NaN                NaN                NaN
# 35    60371011.10         61110091.00        60483449.62        60375712.01
# 36        3491.00           396556.00           34993.35           25218.00
# 37        1286.00             3101.00            2570.46            3101.00
# 38        6952.00           764167.00          193476.41          118920.00
# 39       95982.00           399675.00           96552.67           96377.00
# 40           0.00               96.00               1.48               0.00
# 41           7.00                7.00               7.00               7.00
# 42           1.00                7.00               1.01               1.00
# 43           4.00               13.00               6.00               6.00
# 44           1.00              997.00               1.18               1.00
# 45          10.00             7983.00             319.80             270.00
# 46          10.00             6141.00             278.30             168.00
# 47        1801.00             2015.00            1964.26            1963.00
# 48           1.00               41.00               1.40               1.00
# 49            NaN                 NaN                NaN                NaN
# 50           1.00        251486000.00          170883.58          122590.00
# 51           1.00        282786000.00          420478.99          306086.00
# 52        2000.00             2016.00            2015.00            2015.00
# 53           1.00         90246219.00          252478.03          167042.00
# 54           1.34          3458861.12            5377.61            3991.78
# 55            NaN                 NaN                NaN                NaN
# 56           0.00               99.00              13.89              14.00
# 57          -1.00  483030105084015.00  60484312212574.43  60375715022011.00
#
#                 Std  UniqCnt
# 0        7909966.39      NaN
# 1              3.15      NaN
# 2              2.44      NaN
# 3            538.79      NaN
# 4              1.08      NaN
# 5              1.28      NaN
# 6              0.50      NaN
# 7              1.81      NaN
# 8              1.00      NaN
# 9              0.00      NaN
# 10           632.87      NaN
# 11          1819.78      NaN
# 12           971.06      NaN
# 13           357.07      NaN
# 14          5447.43      NaN
# 15           664.49      NaN
# 16          7695.30      NaN
# 17            20.23      NaN
# 18             0.46      NaN
# 19             0.99      NaN
# 20             0.61      NaN
# 21           245.44      NaN
# 22              NaN      1.0
# 23             3.29      NaN
# 24        243381.18      NaN
# 25        345317.10      NaN
# 26        337592.37      NaN
# 27             0.00      NaN
# 28           191.32      NaN
# 29             0.00      NaN
# 30             0.00      NaN
# 31             0.00      NaN
# 32              NaN    240.0
# 33            15.91      NaN
# 34              NaN   5638.0
# 35        200811.68      NaN
# 36         50727.47      NaN
# 37           788.07      NaN
# 38        165713.25      NaN
# 39          3673.18      NaN
# 40             2.84      NaN
# 41             0.00      NaN
# 42             0.12      NaN
# 43             0.38      NaN
# 44             2.45      NaN
# 45           233.09      NaN
# 46           369.73      NaN
# 47            23.44      NaN
# 48             0.54      NaN
# 49              NaN      1.0
# 50        402068.34      NaN
# 51        726346.65      NaN
# 52             0.04      NaN
# 53        445013.17      NaN
# 54          9183.11      NaN
# 55              NaN      1.0
# 56             2.58      NaN
# 57  324903454737.31      NaN

# %%
train16.head()
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %%
full_info(train16)
# Out:
#           col_name        col_type  Null_Count  Null_Count%          Min           Max  \
# 0         parcelid           int64           0          0.0  10711738.00  162960842.00
# 1         logerror         float64           0          0.0        -4.61          4.74
# 2  transactiondate  datetime64[ns]           0          0.0          NaN           NaN
#
#           Mean          Med         Std  UniqCnt
# 0  12984656.11  12547337.00  2504510.49      NaN
# 1         0.01         0.01        0.16      NaN
# 2          NaN          NaN         NaN      NaN

# %%
print('size of properties_2016.csv: ', prop16.shape)
print('size of train_2016_v2.csv: ', train16.shape)
#print('size of properties_2017.csv: ', prop17.shape)
#print('size of train_2017.csv: ', train17.shape)
# Out:
# size of properties_2016.csv:  (2985217, 58)
# size of train_2016_v2.csv:  (90275, 3)

# %%
unique_props = len(train16['parcelid'].unique())
multiple_sales = len(train16) - unique_props
print('number of unique sales: ', unique_props)
print('Number of duplicate: ', multiple_sales)
# Out:
# number of unique sales:  90150
# Number of duplicate:  125

# %%
smplsub.head()
# Out:
#    ParcelId  201610  201611  201612  201710  201711  201712
# 0  10754147       0       0       0       0       0       0
# 1  10759547       0       0       0       0       0       0
# 2  10843547       0       0       0       0       0       0
# 3  10859147       0       0       0       0       0       0
# 4  10879947       0       0       0       0       0       0

# %%
plt.figure(figsize=(8,6))
plt.scatter(range(train16.shape[0]), np.sort(train16.logerror.values))
plt.xlabel('index', fontsize=12)
plt.ylabel('logerror', fontsize=12)
plt.show()

# %%
missing_prop16 = full_info(prop16)
y_pos = np.arange(missing_prop16.shape[0])
width = 0.9
fig, ax = plt.subplots(figsize=(12,18))
rects = ax.barh(y_pos, sorted(missing_prop16.Null_Count.values), color='gray')
ax.set_yticks(y_pos)
ax.set_yticklabels(missing_prop16.col_name.values, rotation='horizontal')
ax.set_xlabel("Count of missing values")
ax.set_title("Number of missing values in each column")
plt.show()

# %%
train16_merge = pd.merge(prop16, train16, on='parcelid', how='left')
train16_merge.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# 0                NaN         NaN                       NaN
# 1                NaN         NaN                       NaN
# 2                NaN         NaN                       NaN
# 3                NaN         NaN                       NaN
# 4                NaN         NaN                       NaN
#
#    calculatedfinishedsquarefeet  finishedsquarefeet12  finishedsquarefeet13  \
# 0                           NaN                   NaN                   NaN
# 1                           NaN                   NaN                   NaN
# 2                       73026.0                   NaN                   NaN
# 3                        5068.0                   NaN                   NaN
# 4                        1776.0                   NaN                   NaN
#
#    finishedsquarefeet15  finishedsquarefeet50  finishedsquarefeet6    fips  \
# 0                   NaN                   NaN                  NaN  6037.0
# 1                   NaN                   NaN                  NaN  6037.0
# 2               73026.0                   NaN                  NaN  6037.0
# 3                5068.0                   NaN                  NaN  6037.0
# 4                1776.0                   NaN                  NaN  6037.0
#
#    fireplacecnt  fullbathcnt  garagecarcnt  garagetotalsqft hashottuborspa  \
# 0           NaN          NaN           NaN              NaN            NaN
# 1           NaN          NaN           NaN              NaN            NaN
# 2           NaN          NaN           NaN              NaN            NaN
# 3           NaN          NaN           NaN              NaN            NaN
# 4           NaN          NaN           NaN              NaN            NaN
#
#    heatingorsystemtypeid    latitude    longitude  lotsizesquarefeet  poolcnt  \
# 0                    NaN  34144442.0 -118654084.0            85768.0      NaN
# 1                    NaN  34140430.0 -118625364.0             4083.0      NaN
# 2                    NaN  33989359.0 -118394633.0            63085.0      NaN
# 3                    NaN  34148863.0 -118437206.0             7521.0      NaN
# 4                    NaN  34194168.0 -118385816.0             8512.0      NaN
#
#    poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# 0          NaN           NaN          NaN          NaN
# 1          NaN           NaN          NaN          NaN
# 2          NaN           NaN          NaN          NaN
# 3          NaN           NaN          NaN          NaN
# 4          NaN           NaN          NaN          NaN
#
#   propertycountylandusecode  propertylandusetypeid propertyzoningdesc  \
# 0                      010D                  269.0                NaN
# 1                      0109                  261.0             LCA11*
# 2                      1200                   47.0               LAC2
# 3                      1200                   47.0               LAC2
# 4                      1210                   31.0               LAM1
#
#    rawcensustractandblock  regionidcity  regionidcounty  regionidneighborhood  \
# 0            6.037800e+07       37688.0          3101.0                   NaN
# 1            6.037800e+07       37688.0          3101.0                   NaN
# 2            6.037703e+07       51617.0          3101.0                   NaN
# 3            6.037141e+07       12447.0          3101.0               27080.0
# 4            6.037123e+07       12447.0          3101.0               46795.0
#
#    regionidzip  roomcnt  storytypeid  threequarterbathnbr  \
# 0      96337.0      0.0          NaN                  NaN
# 1      96337.0      0.0          NaN                  NaN
# 2      96095.0      0.0          NaN                  NaN
# 3      96424.0      0.0          NaN                  NaN
# 4      96450.0      0.0          NaN                  NaN
#
#    typeconstructiontypeid  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 0                     NaN      NaN                 NaN                 NaN
# 1                     NaN      NaN                 NaN                 NaN
# 2                     NaN      2.0                 NaN                 NaN
# 3                     NaN      NaN                 NaN                 NaN
# 4                     NaN      1.0                 NaN                 NaN
#
#    yearbuilt  numberofstories fireplaceflag  structuretaxvaluedollarcnt  \
# 0        NaN              NaN           NaN                         NaN
# 1        NaN              NaN           NaN                         NaN
# 2        NaN              NaN           NaN                    650756.0
# 3     1948.0              1.0           NaN                    571346.0
# 4     1947.0              NaN           NaN                    193796.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0                9.0          2015.0                    9.0        NaN
# 1            27516.0          2015.0                27516.0        NaN
# 2          1413387.0          2015.0               762631.0   20800.37
# 3          1156834.0          2015.0               585488.0   14557.57
# 4           433491.0          2015.0               239695.0    5725.17
#
#   taxdelinquencyflag  taxdelinquencyyear  censustractandblock  logerror  \
# 0                NaN                 NaN                  NaN       NaN
# 1                NaN                 NaN                  NaN       NaN
# 2                NaN                 NaN                  NaN       NaN
# 3                NaN                 NaN                  NaN       NaN
# 4                NaN                 NaN                  NaN       NaN
#
#   transactiondate
# 0             NaT
# 1             NaT
# 2             NaT
# 3             NaT
# 4             NaT

# %%
full_info(train16_merge)
# Out:
#                         col_name        col_type  Null_Count%            Min  \
# 0                       parcelid           int64         0.00    10711725.00
# 1          airconditioningtypeid         float64        72.82           1.00
# 2       architecturalstyletypeid         float64        99.80           2.00
# 3                   basementsqft         float64        99.95          20.00
# 4                    bathroomcnt         float64         0.38           0.00
# 5                     bedroomcnt         float64         0.38           0.00
# 6            buildingclasstypeid         float64        99.58           1.00
# 7          buildingqualitytypeid         float64        35.06           1.00
# 8              calculatedbathnbr         float64         4.32           1.00
# 9                     decktypeid         float64        99.43          66.00
# 10      finishedfloor1squarefeet         float64        93.21           3.00
# 11  calculatedfinishedsquarefeet         float64         1.86           1.00
# 12          finishedsquarefeet12         float64         9.25           1.00
# 13          finishedsquarefeet13         float64        99.74         120.00
# 14          finishedsquarefeet15         float64        93.61         112.00
# 15          finishedsquarefeet50         float64        93.21           3.00
# 16           finishedsquarefeet6         float64        99.26         117.00
# 17                          fips         float64         0.38        6037.00
# 18                  fireplacecnt         float64        89.53           1.00
# 19                   fullbathcnt         float64         4.32           1.00
# 20                  garagecarcnt         float64        70.41           0.00
# 21               garagetotalsqft         float64        70.41           0.00
# 22                hashottuborspa          object        97.69            NaN
# 23         heatingorsystemtypeid         float64        39.49           1.00
# 24                      latitude         float64         0.38    33324388.00
# 25                     longitude         float64         0.38  -119475780.00
# 26             lotsizesquarefeet         float64         9.25         100.00
# 27                       poolcnt         float64        82.66           1.00
# 28                   poolsizesum         float64        99.06          19.00
# 29                  pooltypeid10         float64        98.76           1.00
# 30                   pooltypeid2         float64        98.93           1.00
# 31                   pooltypeid7         float64        83.74           1.00
# 32     propertycountylandusecode          object         0.41            NaN
# 33         propertylandusetypeid         float64         0.38          31.00
# 34            propertyzoningdesc          object        33.72            NaN
# 35        rawcensustractandblock         float64         0.38    60371011.10
# 36                  regionidcity         float64         2.11        3491.00
# 37                regionidcounty         float64         0.38        1286.00
# 38          regionidneighborhood         float64        61.26        6952.00
# 39                   regionidzip         float64         0.47       95982.00
# 40                       roomcnt         float64         0.38           0.00
# 41                   storytypeid         float64        99.95           7.00
# 42           threequarterbathnbr         float64        89.56           1.00
# 43        typeconstructiontypeid         float64        99.77           4.00
# 44                       unitcnt         float64        33.76           1.00
# 45            yardbuildingsqft17         float64        97.31          10.00
# 46            yardbuildingsqft26         float64        99.91          10.00
# 47                     yearbuilt         float64         2.01        1801.00
# 48               numberofstories         float64        77.15           1.00
# 49                 fireplaceflag          object        99.83            NaN
# 50    structuretaxvaluedollarcnt         float64         1.84           1.00
# 51             taxvaluedollarcnt         float64         1.43           1.00
# 52                assessmentyear         float64         0.38        2000.00
# 53         landtaxvaluedollarcnt         float64         2.27           1.00
# 54                     taxamount         float64         1.05           1.34
# 55            taxdelinquencyflag          object        98.11            NaN
# 56            taxdelinquencyyear         float64        98.11           0.00
# 57           censustractandblock         float64         2.52          -1.00
# 58                      logerror         float64        96.98          -4.61
# 59               transactiondate  datetime64[ns]        96.98            NaN
#
#                    Max               Mean                Med              Std
# 0         169601949.00        13325837.21        12545092.50       7909808.36
# 1                13.00               1.93               1.00             3.15
# 2                27.00               7.20               7.00             2.44
# 3              8516.00             646.88             534.00           538.79
# 4                20.00               2.21               2.00             1.08
# 5                20.00               3.09               3.00             1.28
# 6                 5.00               3.73               4.00             0.50
# 7                12.00               5.78               7.00             1.81
# 8                20.00               2.30               2.00             1.00
# 9                66.00              66.00              66.00             0.00
# 10            31303.00            1380.64            1283.00           632.88
# 11           952576.00            1827.16            1572.00          1819.75
# 12           290345.00            1760.00            1539.00           971.06
# 13             2688.00            1178.90            1296.00           357.07
# 14           820242.00            2739.16            2172.00          5447.30
# 15            31303.00            1388.95            1284.00           664.50
# 16           952576.00            2414.51            1992.00          7694.98
# 17             6111.00            6048.03            6037.00            20.23
# 18                9.00               1.17               1.00             0.46
# 19               20.00               2.24               2.00             0.99
# 20               25.00               1.82               2.00             0.61
# 21             7749.00             383.77             441.00           245.44
# 22                 NaN                NaN                NaN              NaN
# 23               24.00               4.01               2.00             3.29
# 24         34819650.00        34001467.16        34008248.00        243381.64
# 25       -117554316.00      -118201933.34      -118172540.00        345316.85
# 26        328263808.00           22822.75            7000.00        337585.61
# 27                1.00               1.00               1.00             0.00
# 28            17410.00             519.72             495.00           191.32
# 29                1.00               1.00               1.00             0.00
# 30                1.00               1.00               1.00             0.00
# 31                1.00               1.00               1.00             0.00
# 32                 NaN                NaN                NaN              NaN
# 33              275.00             260.05             261.00            15.91
# 34                 NaN                NaN                NaN              NaN
# 35         61110091.00        60483449.29        60375712.01        200810.60
# 36           396556.00           34993.26           25218.00         50726.98
# 37             3101.00            2570.46            3101.00           788.07
# 38           764167.00          193477.27          118920.00        165714.07
# 39           399675.00           96552.67           96377.00          3673.10
# 40               96.00               1.48               0.00             2.84
# 41                7.00               7.00               7.00             0.00
# 42                7.00               1.01               1.00             0.12
# 43               13.00               6.00               6.00             0.38
# 44              997.00               1.18               1.00             2.45
# 45             7983.00             319.80             270.00           233.09
# 46             6141.00             278.30             168.00           369.73
# 47             2015.00            1964.26            1963.00            23.44
# 48               41.00               1.40               1.00             0.54
# 49                 NaN                NaN                NaN              NaN
# 50        251486000.00          170883.66          122590.00        402063.03
# 51        282786000.00          420481.63          306086.00        726341.05
# 52             2016.00            2015.00            2015.00             0.04
# 53         90246219.00          252480.60          167043.00        445011.24
# 54          3458861.12            5377.66            3991.78          9183.03
# 55                 NaN                NaN                NaN              NaN
# 56               99.00              13.89              14.00             2.58
# 57  483030105084015.00  60484311840953.96  60375715022011.00  324898560762.18
# 58                4.74               0.01               0.01             0.16
# 59                 NaN                NaN                NaN              NaN
