# %% [markdown]
# # <span style="color:gray">Zestimate and Actual Sale Price Difference</span>

# %% [markdown]
#  ## <span style="color:black">1. Define</span>
#  Problem -
#  >Predict the log-error between their Zestimate and the actual sale price, given all the features of a home.
#  >
#              log-error=log(Zestimate)−log(SalePrice)
#  >
#  > Predict the logerror for the months in Fall 2017
#
#  What we have -
#  >a full list of real estate properties in three counties (Los Angeles, Orange and Ventura, California) data in 2016.
#  >The train data has all the transactions before October 15, 2016, plus some of the transactions after October 15, 2016.
#  >The test data in the public leaderboard has the rest of the transactions between October 15 and December 31, 2016.
#  >4 Categorical/Qualitative - companyId, jobType, degree, major, industry
#  >2 Numeric/Quantitative - yearsExperience, milesFromMetropolis
#
#  Type of Algorithm -
#  >

# %% [markdown]
#  ## <span style="color:black">2. Discover</span>

# %% [markdown]
# ### <span style="color:black">2.1. Import Libraries</span>

# %%
# %%capture
! pip install seaborn
#import initial libraries
import pandas as pd
import numpy as np
from numpy import NaN
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
pd.set_option('display.max_rows', 70)
pd.set_option('display.max_columns', 70)
#pd.set_option('display.width', 100)

# %%
import os
for dirname, _, filenames in os.walk('C:/Users/Manohar/Documents/DataScience/zillow/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
prop16 = pd.read_csv("/Users/dad/Documents/GitHub/data/zillow/properties_2016.csv")
prop17 = pd.read_csv("/Users/dad/Documents/GitHub/data/zillow/properties_2017.csv")
smplsub = pd.read_csv("/Users/dad/Documents/GitHub/data/zillow/sample_submission.csv")
train16 = pd.read_csv("/Users/dad/Documents/GitHub/data/zillow/train_2016_v2.csv", parse_dates=["transactiondate"])
train17 = pd.read_csv("/Users/dad/Documents/GitHub/data/zillow/train_2017.csv", parse_dates=["transactiondate"])
# Out:
# /Users/dad/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (22,32,34,49,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/dad/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
prop16.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# 0                NaN         NaN                       NaN
# 1                NaN         NaN                       NaN
# 2                NaN         NaN                       NaN
# 3                NaN         NaN                       NaN
# 4                NaN         NaN                       NaN
#
#    calculatedfinishedsquarefeet  finishedsquarefeet12  finishedsquarefeet13  \
# 0                           NaN                   NaN                   NaN
# 1                           NaN                   NaN                   NaN
# 2                       73026.0                   NaN                   NaN
# 3                        5068.0                   NaN                   NaN
# 4                        1776.0                   NaN                   NaN
#
#    finishedsquarefeet15  finishedsquarefeet50  finishedsquarefeet6    fips  \
# 0                   NaN                   NaN                  NaN  6037.0
# 1                   NaN                   NaN                  NaN  6037.0
# 2               73026.0                   NaN                  NaN  6037.0
# 3                5068.0                   NaN                  NaN  6037.0
# 4                1776.0                   NaN                  NaN  6037.0
#
#    fireplacecnt  fullbathcnt  garagecarcnt  garagetotalsqft hashottuborspa  \
# 0           NaN          NaN           NaN              NaN            NaN
# 1           NaN          NaN           NaN              NaN            NaN
# 2           NaN          NaN           NaN              NaN            NaN
# 3           NaN          NaN           NaN              NaN            NaN
# 4           NaN          NaN           NaN              NaN            NaN
#
#    heatingorsystemtypeid    latitude    longitude  lotsizesquarefeet  poolcnt  \
# 0                    NaN  34144442.0 -118654084.0            85768.0      NaN
# 1                    NaN  34140430.0 -118625364.0             4083.0      NaN
# 2                    NaN  33989359.0 -118394633.0            63085.0      NaN
# 3                    NaN  34148863.0 -118437206.0             7521.0      NaN
# 4                    NaN  34194168.0 -118385816.0             8512.0      NaN
#
#    poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# 0          NaN           NaN          NaN          NaN
# 1          NaN           NaN          NaN          NaN
# 2          NaN           NaN          NaN          NaN
# 3          NaN           NaN          NaN          NaN
# 4          NaN           NaN          NaN          NaN
#
#   propertycountylandusecode  propertylandusetypeid propertyzoningdesc  \
# 0                      010D                  269.0                NaN
# 1                      0109                  261.0             LCA11*
# 2                      1200                   47.0               LAC2
# 3                      1200                   47.0               LAC2
# 4                      1210                   31.0               LAM1
#
#    rawcensustractandblock  regionidcity  regionidcounty  regionidneighborhood  \
# 0            6.037800e+07       37688.0          3101.0                   NaN
# 1            6.037800e+07       37688.0          3101.0                   NaN
# 2            6.037703e+07       51617.0          3101.0                   NaN
# 3            6.037141e+07       12447.0          3101.0               27080.0
# 4            6.037123e+07       12447.0          3101.0               46795.0
#
#    regionidzip  roomcnt  storytypeid  threequarterbathnbr  \
# 0      96337.0      0.0          NaN                  NaN
# 1      96337.0      0.0          NaN                  NaN
# 2      96095.0      0.0          NaN                  NaN
# 3      96424.0      0.0          NaN                  NaN
# 4      96450.0      0.0          NaN                  NaN
#
#    typeconstructiontypeid  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 0                     NaN      NaN                 NaN                 NaN
# 1                     NaN      NaN                 NaN                 NaN
# 2                     NaN      2.0                 NaN                 NaN
# 3                     NaN      NaN                 NaN                 NaN
# 4                     NaN      1.0                 NaN                 NaN
#
#    yearbuilt  numberofstories fireplaceflag  structuretaxvaluedollarcnt  \
# 0        NaN              NaN           NaN                         NaN
# 1        NaN              NaN           NaN                         NaN
# 2        NaN              NaN           NaN                    650756.0
# 3     1948.0              1.0           NaN                    571346.0
# 4     1947.0              NaN           NaN                    193796.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0                9.0          2015.0                    9.0        NaN
# 1            27516.0          2015.0                27516.0        NaN
# 2          1413387.0          2015.0               762631.0   20800.37
# 3          1156834.0          2015.0               585488.0   14557.57
# 4           433491.0          2015.0               239695.0    5725.17
#
#   taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 0                NaN                 NaN                  NaN
# 1                NaN                 NaN                  NaN
# 2                NaN                 NaN                  NaN
# 3                NaN                 NaN                  NaN
# 4                NaN                 NaN                  NaN

# %%
def num_after_point(x):
    s = str(x)
    if not '.' in s:
        return 0
    return len(s) - s.index('.') - 1

# %%
def full_info(df):
    df_column=[]
    df_dtype=[]
    df_null=[]
    df_nullc=[]
    df_mean=[]
    df_median=[]
    df_std=[]
    df_min=[]
    df_max=[]
    df_uniq=[]
    for col in df.columns: 
        df_column.append( col)
        df_dtype.append( df[col].dtype)
        df_null.append( round(100 * df[col].isnull().sum(axis=0)/len(df[col]),2))
        df_nullc.append( df[col].isnull().sum(axis=0))
        df_uniq.append( df[col].nunique()) if df[col].dtype == 'object' else df_uniq.append( NaN)
        df_mean.append(  '{0:.2f}'.format(df[col].mean())) if df[col].dtype == 'int64' or df[col].dtype == 'float64' else df_mean.append( NaN)
        df_median.append( '{0:.2f}'.format(df[col].median())) if df[col].dtype == 'int64' or df[col].dtype == 'float64' else df_median.append( NaN)
        df_std.append( '{0:.2f}'.format(df[col].std())) if df[col].dtype == 'int64' or df[col].dtype == 'float64' else df_std.append( NaN)
        df_max.append( '{0:.2f}'.format(df[col].max())) if df[col].dtype == 'int64' or df[col].dtype == 'float64' else df_max.append( NaN)
        df_min.append( '{0:.2f}'.format(df[col].min())) if df[col].dtype == 'int64' or df[col].dtype == 'float64' else df_min.append( NaN)
    return pd.DataFrame(data = {'ColName': df_column, 'ColType': df_dtype, 'NullCnt': df_nullc, 'NullCntPrcntg': df_null,  'Min': df_min, 'Max': df_max, 'Mean': df_mean, 'Med': df_median, 'Std': df_std, 'UniqCnt': df_uniq})

# %%
prop16_Info = full_info(prop16)
prop16_Info.sort_values(by=['NullCnt'], ascending=False, inplace=True, ignore_index=True)
prop16_Info
# Out:
#                          ColName  ColType  NullCnt  NullCntPrcntg  \
# 0                    storytypeid  float64  2983593          99.95
# 1                   basementsqft  float64  2983589          99.95
# 2             yardbuildingsqft26  float64  2982570          99.91
# 3                  fireplaceflag   object  2980054          99.83
# 4       architecturalstyletypeid  float64  2979156          99.80
# 5         typeconstructiontypeid  float64  2978470          99.77
# 6           finishedsquarefeet13  float64  2977545          99.74
# 7            buildingclasstypeid  float64  2972588          99.58
# 8                     decktypeid  float64  2968121          99.43
# 9            finishedsquarefeet6  float64  2963216          99.26
# 10                   poolsizesum  float64  2957257          99.06
# 11                   pooltypeid2  float64  2953142          98.93
# 12                  pooltypeid10  float64  2948278          98.76
# 13            taxdelinquencyflag   object  2928755          98.11
# 14            taxdelinquencyyear  float64  2928753          98.11
# 15                hashottuborspa   object  2916203          97.69
# 16            yardbuildingsqft17  float64  2904862          97.31
# 17          finishedsquarefeet15  float64  2794419          93.61
# 18          finishedsquarefeet50  float64  2782500          93.21
# 19      finishedfloor1squarefeet  float64  2782500          93.21
# 20           threequarterbathnbr  float64  2673586          89.56
# 21                  fireplacecnt  float64  2672580          89.53
# 22                   pooltypeid7  float64  2499758          83.74
# 23                       poolcnt  float64  2467683          82.66
# 24               numberofstories  float64  2303148          77.15
# 25         airconditioningtypeid  float64  2173698          72.82
# 26               garagetotalsqft  float64  2101950          70.41
# 27                  garagecarcnt  float64  2101950          70.41
# 28          regionidneighborhood  float64  1828815          61.26
# 29         heatingorsystemtypeid  float64  1178816          39.49
# 30         buildingqualitytypeid  float64  1046729          35.06
# 31                       unitcnt  float64  1007727          33.76
# 32            propertyzoningdesc   object  1006588          33.72
# 33             lotsizesquarefeet  float64   276099           9.25
# 34          finishedsquarefeet12  float64   276033           9.25
# 35             calculatedbathnbr  float64   128912           4.32
# 36                   fullbathcnt  float64   128912           4.32
# 37           censustractandblock  float64    75126           2.52
# 38         landtaxvaluedollarcnt  float64    67733           2.27
# 39                  regionidcity  float64    62845           2.11
# 40                     yearbuilt  float64    59928           2.01
# 41  calculatedfinishedsquarefeet  float64    55565           1.86
# 42    structuretaxvaluedollarcnt  float64    54982           1.84
# 43             taxvaluedollarcnt  float64    42550           1.43
# 44                     taxamount  float64    31250           1.05
# 45                   regionidzip  float64    13980           0.47
# 46     propertycountylandusecode   object    12277           0.41
# 47                       roomcnt  float64    11475           0.38
# 48                   bathroomcnt  float64    11462           0.38
# 49                    bedroomcnt  float64    11450           0.38
# 50                assessmentyear  float64    11439           0.38
# 51                regionidcounty  float64    11437           0.38
# 52                          fips  float64    11437           0.38
# 53                      latitude  float64    11437           0.38
# 54                     longitude  float64    11437           0.38
# 55         propertylandusetypeid  float64    11437           0.38
# 56        rawcensustractandblock  float64    11437           0.38
# 57                      parcelid    int64        0           0.00
#
#               Min                 Max               Mean                Med  \
# 0            7.00                7.00               7.00               7.00
# 1           20.00             8516.00             646.88             534.00
# 2           10.00             6141.00             278.30             168.00
# 3             NaN                 NaN                NaN                NaN
# 4            2.00               27.00               7.20               7.00
# 5            4.00               13.00               6.00               6.00
# 6          120.00             2688.00            1178.90            1296.00
# 7            1.00                5.00               3.73               4.00
# 8           66.00               66.00              66.00              66.00
# 9          117.00           952576.00            2414.34            1992.00
# 10          19.00            17410.00             519.71             495.00
# 11           1.00                1.00               1.00               1.00
# 12           1.00                1.00               1.00               1.00
# 13            NaN                 NaN                NaN                NaN
# 14           0.00               99.00              13.89              14.00
# 15            NaN                 NaN                NaN                NaN
# 16          10.00             7983.00             319.80             270.00
# 17         112.00           820242.00            2739.19            2172.00
# 18           3.00            31303.00            1388.94            1284.00
# 19           3.00            31303.00            1380.63            1283.00
# 20           1.00                7.00               1.01               1.00
# 21           1.00                9.00               1.17               1.00
# 22           1.00                1.00               1.00               1.00
# 23           1.00                1.00               1.00               1.00
# 24           1.00               41.00               1.40               1.00
# 25           1.00               13.00               1.93               1.00
# 26           0.00             7749.00             383.77             441.00
# 27           0.00               25.00               1.82               2.00
# 28        6952.00           764167.00          193476.41          118920.00
# 29           1.00               24.00               4.01               2.00
# 30           1.00               12.00               5.78               7.00
# 31           1.00              997.00               1.18               1.00
# 32            NaN                 NaN                NaN                NaN
# 33         100.00        328263808.00           22822.81            7000.00
# 34           1.00           290345.00            1760.00            1539.00
# 35           1.00               20.00               2.30               2.00
# 36           1.00               20.00               2.24               2.00
# 37          -1.00  483030105084015.00  60484312212574.43  60375715022011.00
# 38           1.00         90246219.00          252478.03          167042.00
# 39        3491.00           396556.00           34993.35           25218.00
# 40        1801.00             2015.00            1964.26            1963.00
# 41           1.00           952576.00            1827.16            1572.00
# 42           1.00        251486000.00          170883.58          122590.00
# 43           1.00        282786000.00          420478.99          306086.00
# 44           1.34          3458861.12            5377.61            3991.78
# 45       95982.00           399675.00           96552.67           96377.00
# 46            NaN                 NaN                NaN                NaN
# 47           0.00               96.00               1.48               0.00
# 48           0.00               20.00               2.21               2.00
# 49           0.00               20.00               3.09               3.00
# 50        2000.00             2016.00            2015.00            2015.00
# 51        1286.00             3101.00            2570.46            3101.00
# 52        6037.00             6111.00            6048.03            6037.00
# 53    33324388.00         34819650.00        34001468.65        34008249.00
# 54  -119475780.00       -117554316.00      -118201934.16      -118172540.50
# 55          31.00              275.00             260.05             261.00
# 56    60371011.10         61110091.00        60483449.62        60375712.01
# 57    10711725.00        169601949.00        13325858.36        12545094.00
#
#                 Std  UniqCnt
# 0              0.00      NaN
# 1            538.79      NaN
# 2            369.73      NaN
# 3               NaN      1.0
# 4              2.44      NaN
# 5              0.38      NaN
# 6            357.07      NaN
# 7              0.50      NaN
# 8              0.00      NaN
# 9           7695.30      NaN
# 10           191.32      NaN
# 11             0.00      NaN
# 12             0.00      NaN
# 13              NaN      1.0
# 14             2.58      NaN
# 15              NaN      1.0
# 16           233.09      NaN
# 17          5447.43      NaN
# 18           664.49      NaN
# 19           632.87      NaN
# 20             0.12      NaN
# 21             0.46      NaN
# 22             0.00      NaN
# 23             0.00      NaN
# 24             0.54      NaN
# 25             3.15      NaN
# 26           245.44      NaN
# 27             0.61      NaN
# 28        165713.25      NaN
# 29             3.29      NaN
# 30             1.81      NaN
# 31             2.45      NaN
# 32              NaN   5638.0
# 33        337592.37      NaN
# 34           971.06      NaN
# 35             1.00      NaN
# 36             0.99      NaN
# 37  324903454737.31      NaN
# 38        445013.17      NaN
# 39         50727.47      NaN
# 40            23.44      NaN
# 41          1819.78      NaN
# 42        402068.34      NaN
# 43        726346.65      NaN
# 44          9183.11      NaN
# 45          3673.18      NaN
# 46              NaN    240.0
# 47             2.84      NaN
# 48             1.08      NaN
# 49             1.28      NaN
# 50             0.04      NaN
# 51           788.07      NaN
# 52            20.23      NaN
# 53        243381.18      NaN
# 54        345317.10      NaN
# 55            15.91      NaN
# 56        200811.68      NaN
# 57       7909966.39      NaN

# %%
prop16[['taxvaluedollarcnt', 'taxamount']]
# Out:
#          taxvaluedollarcnt  taxamount
# 0                      9.0        NaN
# 1                  27516.0        NaN
# 2                1413387.0   20800.37
# 3                1156834.0   14557.57
# 4                 433491.0    5725.17
# ...                    ...        ...
# 2985212                NaN        NaN
# 2985213                NaN        NaN
# 2985214                NaN        NaN
# 2985215                NaN        NaN
# 2985216                NaN        NaN
#
# [2985217 rows x 2 columns]

# %%
train16.head()
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %%
full_info(train16)
# Out:
#            ColName         ColType  NullCnt  NullCntPrcntg          Min  \
# 0         parcelid           int64        0            0.0  10711738.00
# 1         logerror         float64        0            0.0        -4.61
# 2  transactiondate  datetime64[ns]        0            0.0          NaN
#
#             Max         Mean          Med         Std  UniqCnt
# 0  162960842.00  12984656.11  12547337.00  2504510.49      NaN
# 1          4.74         0.01         0.01        0.16      NaN
# 2           NaN          NaN          NaN         NaN      NaN

# %%
print('size of properties_2016.csv: ', prop16.shape)
print('size of train_2016_v2.csv: ', train16.shape)
#print('size of properties_2017.csv: ', prop17.shape)
#print('size of train_2017.csv: ', train17.shape)
# Out:
# size of properties_2016.csv:  (2985217, 58)
# size of train_2016_v2.csv:  (90275, 3)

# %%
unique_props = len(train16['parcelid'].unique())
multiple_sales = len(train16) - unique_props
print('number of unique sales: ', unique_props)
print('Number of duplicate: ', multiple_sales)
# Out:
# number of unique sales:  90150
# Number of duplicate:  125

# %%
smplsub.head()
# Out:
#    ParcelId  201610  201611  201612  201710  201711  201712
# 0  10754147       0       0       0       0       0       0
# 1  10759547       0       0       0       0       0       0
# 2  10843547       0       0       0       0       0       0
# 3  10859147       0       0       0       0       0       0
# 4  10879947       0       0       0       0       0       0

# %%
prop16_Info.plot.bar(x = 'ColName', y = 'NullCnt', figsize=(20, 5),rot=90, title='Missing (null) Feature Values')

# %%
prop16_trim = prop16.drop(prop16_Info[(prop16_Info.NullCntPrcntg>=90)].ColName.values.tolist(),
                    axis=1)

# %%
prop16_trim
# Out:
#           parcelid  airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 0         10754147                    NaN          0.0         0.0
# 1         10759547                    NaN          0.0         0.0
# 2         10843547                    NaN          0.0         0.0
# 3         10859147                    NaN          0.0         0.0
# 4         10879947                    NaN          0.0         0.0
# ...            ...                    ...          ...         ...
# 2985212  168176230                    NaN          NaN         NaN
# 2985213   14273630                    NaN          NaN         NaN
# 2985214  168040630                    NaN          NaN         NaN
# 2985215  168040830                    NaN          NaN         NaN
# 2985216  168040430                    NaN          NaN         NaN
#
#          buildingqualitytypeid  calculatedbathnbr  \
# 0                          NaN                NaN
# 1                          NaN                NaN
# 2                          NaN                NaN
# 3                          7.0                NaN
# 4                          NaN                NaN
# ...                        ...                ...
# 2985212                    NaN                NaN
# 2985213                    NaN                NaN
# 2985214                    NaN                NaN
# 2985215                    NaN                NaN
# 2985216                    NaN                NaN
#
#          calculatedfinishedsquarefeet  finishedsquarefeet12    fips  \
# 0                                 NaN                   NaN  6037.0
# 1                                 NaN                   NaN  6037.0
# 2                             73026.0                   NaN  6037.0
# 3                              5068.0                   NaN  6037.0
# 4                              1776.0                   NaN  6037.0
# ...                               ...                   ...     ...
# 2985212                           NaN                   NaN     NaN
# 2985213                           NaN                   NaN     NaN
# 2985214                           NaN                   NaN     NaN
# 2985215                           NaN                   NaN     NaN
# 2985216                           NaN                   NaN     NaN
#
#          fireplacecnt  fullbathcnt  garagecarcnt  garagetotalsqft  \
# 0                 NaN          NaN           NaN              NaN
# 1                 NaN          NaN           NaN              NaN
# 2                 NaN          NaN           NaN              NaN
# 3                 NaN          NaN           NaN              NaN
# 4                 NaN          NaN           NaN              NaN
# ...               ...          ...           ...              ...
# 2985212           NaN          NaN           NaN              NaN
# 2985213           NaN          NaN           NaN              NaN
# 2985214           NaN          NaN           NaN              NaN
# 2985215           NaN          NaN           NaN              NaN
# 2985216           NaN          NaN           NaN              NaN
#
#          heatingorsystemtypeid    latitude    longitude  lotsizesquarefeet  \
# 0                          NaN  34144442.0 -118654084.0            85768.0
# 1                          NaN  34140430.0 -118625364.0             4083.0
# 2                          NaN  33989359.0 -118394633.0            63085.0
# 3                          NaN  34148863.0 -118437206.0             7521.0
# 4                          NaN  34194168.0 -118385816.0             8512.0
# ...                        ...         ...          ...                ...
# 2985212                    NaN         NaN          NaN                NaN
# 2985213                    NaN         NaN          NaN                NaN
# 2985214                    NaN         NaN          NaN                NaN
# 2985215                    NaN         NaN          NaN                NaN
# 2985216                    NaN         NaN          NaN                NaN
#
#          poolcnt  pooltypeid7 propertycountylandusecode  \
# 0            NaN          NaN                      010D
# 1            NaN          NaN                      0109
# 2            NaN          NaN                      1200
# 3            NaN          NaN                      1200
# 4            NaN          NaN                      1210
# ...          ...          ...                       ...
# 2985212      NaN          NaN                       NaN
# 2985213      NaN          NaN                       NaN
# 2985214      NaN          NaN                       NaN
# 2985215      NaN          NaN                       NaN
# 2985216      NaN          NaN                       NaN
#
#          propertylandusetypeid propertyzoningdesc  rawcensustractandblock  \
# 0                        269.0                NaN            6.037800e+07
# 1                        261.0             LCA11*            6.037800e+07
# 2                         47.0               LAC2            6.037703e+07
# 3                         47.0               LAC2            6.037141e+07
# 4                         31.0               LAM1            6.037123e+07
# ...                        ...                ...                     ...
# 2985212                    NaN                NaN                     NaN
# 2985213                    NaN                NaN                     NaN
# 2985214                    NaN                NaN                     NaN
# 2985215                    NaN                NaN                     NaN
# 2985216                    NaN                NaN                     NaN
#
#          regionidcity  regionidcounty  regionidneighborhood  regionidzip  \
# 0             37688.0          3101.0                   NaN      96337.0
# 1             37688.0          3101.0                   NaN      96337.0
# 2             51617.0          3101.0                   NaN      96095.0
# 3             12447.0          3101.0               27080.0      96424.0
# 4             12447.0          3101.0               46795.0      96450.0
# ...               ...             ...                   ...          ...
# 2985212           NaN             NaN                   NaN          NaN
# 2985213           NaN             NaN                   NaN          NaN
# 2985214           NaN             NaN                   NaN          NaN
# 2985215           NaN             NaN                   NaN          NaN
# 2985216           NaN             NaN                   NaN          NaN
#
#          roomcnt  threequarterbathnbr  unitcnt  yearbuilt  numberofstories  \
# 0            0.0                  NaN      NaN        NaN              NaN
# 1            0.0                  NaN      NaN        NaN              NaN
# 2            0.0                  NaN      2.0        NaN              NaN
# 3            0.0                  NaN      NaN     1948.0              1.0
# 4            0.0                  NaN      1.0     1947.0              NaN
# ...          ...                  ...      ...        ...              ...
# 2985212      NaN                  NaN      NaN        NaN              NaN
# 2985213      NaN                  NaN      NaN        NaN              NaN
# 2985214      NaN                  NaN      NaN        NaN              NaN
# 2985215      NaN                  NaN      NaN        NaN              NaN
# 2985216      NaN                  NaN      NaN        NaN              NaN
#
#          structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 0                               NaN                9.0          2015.0
# 1                               NaN            27516.0          2015.0
# 2                          650756.0          1413387.0          2015.0
# 3                          571346.0          1156834.0          2015.0
# 4                          193796.0           433491.0          2015.0
# ...                             ...                ...             ...
# 2985212                         NaN                NaN             NaN
# 2985213                         NaN                NaN             NaN
# 2985214                         NaN                NaN             NaN
# 2985215                         NaN                NaN             NaN
# 2985216                         NaN                NaN             NaN
#
#          landtaxvaluedollarcnt  taxamount  censustractandblock
# 0                          9.0        NaN                  NaN
# 1                      27516.0        NaN                  NaN
# 2                     762631.0   20800.37                  NaN
# 3                     585488.0   14557.57                  NaN
# 4                     239695.0    5725.17                  NaN
# ...                        ...        ...                  ...
# 2985212                    NaN        NaN                  NaN
# 2985213                    NaN        NaN                  NaN
# 2985214                    NaN        NaN                  NaN
# 2985215                    NaN        NaN                  NaN
# 2985216                    NaN        NaN                  NaN
#
# [2985217 rows x 38 columns]

# %%
prop16_trim.select_dtypes(include=['object']).columns
# Out:
# Index(['propertycountylandusecode', 'propertyzoningdesc'], dtype='object')

# %%
prop16_trim[['propertycountylandusecode', 'propertyzoningdesc']]
# Out:
#         propertycountylandusecode propertyzoningdesc
# 0                            010D                NaN
# 1                            0109             LCA11*
# 2                            1200               LAC2
# 3                            1200               LAC2
# 4                            1210               LAM1
# ...                           ...                ...
# 2985212                       NaN                NaN
# 2985213                       NaN                NaN
# 2985214                       NaN                NaN
# 2985215                       NaN                NaN
# 2985216                       NaN                NaN
#
# [2985217 rows x 2 columns]

# %%
 prop16_trim=prop16_trim.drop(['propertycountylandusecode', 'propertyzoningdesc'],axis=1)

# %%
prop16_mean_imputed = prop16_trim.fillna(prop16_trim.mean())
prop16_mean_imputed
# Out:
#           parcelid  airconditioningtypeid  bathroomcnt  bedroomcnt  \
# 0         10754147               1.931166     0.000000    0.000000
# 1         10759547               1.931166     0.000000    0.000000
# 2         10843547               1.931166     0.000000    0.000000
# 3         10859147               1.931166     0.000000    0.000000
# 4         10879947               1.931166     0.000000    0.000000
# ...            ...                    ...          ...         ...
# 2985212  168176230               1.931166     2.209143    3.088949
# 2985213   14273630               1.931166     2.209143    3.088949
# 2985214  168040630               1.931166     2.209143    3.088949
# 2985215  168040830               1.931166     2.209143    3.088949
# 2985216  168040430               1.931166     2.209143    3.088949
#
#          buildingqualitytypeid  calculatedbathnbr  \
# 0                     5.784787           2.299263
# 1                     5.784787           2.299263
# 2                     5.784787           2.299263
# 3                     7.000000           2.299263
# 4                     5.784787           2.299263
# ...                        ...                ...
# 2985212               5.784787           2.299263
# 2985213               5.784787           2.299263
# 2985214               5.784787           2.299263
# 2985215               5.784787           2.299263
# 2985216               5.784787           2.299263
#
#          calculatedfinishedsquarefeet  finishedsquarefeet12       fips  \
# 0                         1827.162124           1760.000608  6037.0000
# 1                         1827.162124           1760.000608  6037.0000
# 2                        73026.000000           1760.000608  6037.0000
# 3                         5068.000000           1760.000608  6037.0000
# 4                         1776.000000           1760.000608  6037.0000
# ...                               ...                   ...        ...
# 2985212                   1827.162124           1760.000608  6048.0316
# 2985213                   1827.162124           1760.000608  6048.0316
# 2985214                   1827.162124           1760.000608  6048.0316
# 2985215                   1827.162124           1760.000608  6048.0316
# 2985216                   1827.162124           1760.000608  6048.0316
#
#          fireplacecnt  fullbathcnt  garagecarcnt  garagetotalsqft  \
# 0             1.16871     2.244165      1.823517       383.769357
# 1             1.16871     2.244165      1.823517       383.769357
# 2             1.16871     2.244165      1.823517       383.769357
# 3             1.16871     2.244165      1.823517       383.769357
# 4             1.16871     2.244165      1.823517       383.769357
# ...               ...          ...           ...              ...
# 2985212       1.16871     2.244165      1.823517       383.769357
# 2985213       1.16871     2.244165      1.823517       383.769357
# 2985214       1.16871     2.244165      1.823517       383.769357
# 2985215       1.16871     2.244165      1.823517       383.769357
# 2985216       1.16871     2.244165      1.823517       383.769357
#
#          heatingorsystemtypeid      latitude     longitude  lotsizesquarefeet  \
# 0                     4.012053  3.414444e+07 -1.186541e+08       85768.000000
# 1                     4.012053  3.414043e+07 -1.186254e+08        4083.000000
# 2                     4.012053  3.398936e+07 -1.183946e+08       63085.000000
# 3                     4.012053  3.414886e+07 -1.184372e+08        7521.000000
# 4                     4.012053  3.419417e+07 -1.183858e+08        8512.000000
# ...                        ...           ...           ...                ...
# 2985212               4.012053  3.400147e+07 -1.182019e+08       22822.805528
# 2985213               4.012053  3.400147e+07 -1.182019e+08       22822.805528
# 2985214               4.012053  3.400147e+07 -1.182019e+08       22822.805528
# 2985215               4.012053  3.400147e+07 -1.182019e+08       22822.805528
# 2985216               4.012053  3.400147e+07 -1.182019e+08       22822.805528
#
#          poolcnt  pooltypeid7  propertylandusetypeid  rawcensustractandblock  \
# 0            1.0          1.0             269.000000            6.037800e+07
# 1            1.0          1.0             261.000000            6.037800e+07
# 2            1.0          1.0              47.000000            6.037703e+07
# 3            1.0          1.0              47.000000            6.037141e+07
# 4            1.0          1.0              31.000000            6.037123e+07
# ...          ...          ...                    ...                     ...
# 2985212      1.0          1.0             260.048429            6.048345e+07
# 2985213      1.0          1.0             260.048429            6.048345e+07
# 2985214      1.0          1.0             260.048429            6.048345e+07
# 2985215      1.0          1.0             260.048429            6.048345e+07
# 2985216      1.0          1.0             260.048429            6.048345e+07
#
#          regionidcity  regionidcounty  regionidneighborhood  regionidzip  \
# 0        37688.000000     3101.000000         193476.407415   96337.0000
# 1        37688.000000     3101.000000         193476.407415   96337.0000
# 2        51617.000000     3101.000000         193476.407415   96095.0000
# 3        12447.000000     3101.000000          27080.000000   96424.0000
# 4        12447.000000     3101.000000          46795.000000   96450.0000
# ...               ...             ...                   ...          ...
# 2985212  34993.350224     2570.460554         193476.407415   96552.6728
# 2985213  34993.350224     2570.460554         193476.407415   96552.6728
# 2985214  34993.350224     2570.460554         193476.407415   96552.6728
# 2985215  34993.350224     2570.460554         193476.407415   96552.6728
# 2985216  34993.350224     2570.460554         193476.407415   96552.6728
#
#           roomcnt  threequarterbathnbr   unitcnt    yearbuilt  \
# 0        0.000000             1.010009  1.181171  1964.261641
# 1        0.000000             1.010009  1.181171  1964.261641
# 2        0.000000             1.010009  2.000000  1964.261641
# 3        0.000000             1.010009  1.181171  1948.000000
# 4        0.000000             1.010009  1.000000  1947.000000
# ...           ...                  ...       ...          ...
# 2985212  1.475018             1.010009  1.181171  1964.261641
#          landtaxvaluedollarcnt  taxamount  censustractandblock  logerror  \
# 0                          9.0    3991.78         6.037572e+13       NaN
# 1                      27516.0    3991.78         6.037572e+13       NaN
# 2                     762631.0   20800.37         6.037572e+13       NaN
# 3                     585488.0   14557.57         6.037572e+13       NaN
# 4                     239695.0    5725.17         6.037572e+13       NaN
# ...                        ...        ...                  ...       ...
# 2985337               167042.0    3991.78         6.037572e+13       NaN
# 2985338               167042.0    3991.78         6.037572e+13       NaN
# 2985339               167042.0    3991.78         6.037572e+13       NaN
# 2985340               167042.0    3991.78         6.037572e+13       NaN
# 2985341               167042.0    3991.78         6.037572e+13       NaN
#
#         transactiondate
# 0                   NaT
# 1                   NaT
# 2                   NaT
# 3                   NaT
# 4                   NaT
# ...                 ...
# 2985337             NaT
# 2985338             NaT
# 2985339             NaT
# 2985340             NaT
# 2985341             NaT
#
# [2985342 rows x 38 columns]

# %%
 train16_merge=train16_merge.drop(['parcelid'],axis=1)

# %%
train16_merge['propage'] = 2018 - train16_merge['yearbuilt']  # property age
train16_merge['propage']
# Out:
# 0          55.0
# 1          55.0
# 2          55.0
# 3          70.0
# 4          71.0
#            ...
# 2985337    55.0
# 2985338    55.0
# 2985339    55.0
# 2985340    55.0
# 2985341    55.0
# Name: propage, Length: 2985342, dtype: float64

# %%
import lightgbm as lgb
import random

# %%
#x_train = x_train.values.astype(np.float32, copy=False)

# %%
x_train = train16_merge.drop(columns =[ 'logerror', 'transactiondate', 'fireplacecnt']).values # np array
y_train = train16_merge['logerror'].values  # np array
x_test = train16_merge.drop([ 'logerror', 'transactiondate', 'fireplacecnt'], axis=1).values  # np array
train_columns = train16_merge.drop(columns = [ 'logerror', 'transactiondate', 'fireplacecnt']).columns

# %%
d_train = lgb.Dataset(x_train, y_train, feature_name=['airconditioningtypeid', 'bathroomcnt', 'bedroomcnt',
       'buildingqualitytypeid', 'calculatedbathnbr',
       'calculatedfinishedsquarefeet', 'finishedsquarefeet', 'fips',
       'fullbathcnt', 'garagecarcnt', 'garagetotalsqft',
       'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet',
       'poolcnt', 'pooltypeid', 'propertylandusetypeid',
       'rawcensustractandblock', 'regionidcity', 'regionidcounty',
       'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr',
       'unitcnt', 'yearbuilt', 'numberofstories', 'structuretaxvaluedollarcnt',
       'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
       'taxamount', 'censustractandblock', 'propage'])  # lightgbm data model

# %%
params = {}
params['max_bin'] = 10
params['learning_rate'] = 0.01  # shrinkage_rate 0.0021 grid search = 0.01
params['boosting_type'] = 'gbdt'
params['objective'] = 'regression'
params['metric'] = 'mae'  # l1
params['sub_feature'] = 0.5  # feature_fraction
params['bagging_fraction'] = 0.85  # sub_row
params['num_leaves'] = 512  # num_leaf
params['min_data'] = 500  # min_data_in_leaf
params['min_hessian'] = 0.05  # min_sum_hessian_in_leaf
params['verbose'] = 0
params['feature_fraction_seed'] = 2
params['bagging_seed'] = 3
#params['n_estimators'] = 10  # grid search
params['colsample_bytree'] = 0.85
params['num_leaves'] = 22
params['subsample'] = 0.7

np.random.seed(0)
random.seed(0)

clf = lgb.train(params, d_train, 430)

# %%
#x_test = x_test.values.astype(np.float32, copy=False)

p_test = clf.predict(x_test)

# %%
pd.DataFrame(p_test).head()
# Out:
#           0
# 0 -0.000213
# 1 -0.000235
# 2  0.000263
# 3 -0.000371
# 4 -0.000226

# %%
lgb.plot_importance(clf, figsize=(20,20))

# %%
import os
os.environ["PATH"] += os.pathsep + '/opt/anaconda3/lib/python3.7/site-packages/sphinx/templates/graphviz'
lgb.plot_tree(clf, figsize=(140,20))

# %%
from dtreeplt import dtreeplt
dtree = dtreeplt(model = clf, feature_names=train_columns,  target_names=['logerror'], filled=True)
dtree.view()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-a0d2d8eeea82> in <module>
#       1 from dtreeplt import dtreeplt
#       2 dtree = dtreeplt(model = clf, feature_names=train_columns,  target_names=['logerror'], filled=True)
# ----> 3 dtree.view()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/dtreeplt/dtreeplt.py in view(self, interactive)
#     277             fig: matplotlib.figure object
#     278         '''
# --> 279         x_dict, tree_info_dict = self._calc_nodes_relation()
#     280
#     281         if interactive:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/dtreeplt/dtreeplt.py in _calc_nodes_relation(self)
#      92
#      93     def _calc_nodes_relation(self):
# ---> 94         tree_info_dict = self._get_tree_infomation()
#      95         self.classes, self.class_ids = self._get_class_names(tree_info_dict['values'])
#      96         links = []
#
# ~/opt/anaconda3/lib/python3.7/site-packages/dtreeplt/dtreeplt.py in _get_tree_infomation(self)
#      71     def _get_tree_infomation(self):
#      72         tree_info_dict = {}
# ---> 73         tree_info_dict['samples'] = self.model.tree_.n_node_samples
#      74         tree_info_dict['values'] = self.model.tree_.value
#      75         tree_info_dict['features'] = [self.feature_names[i] if i >=0 else 'target' for i in self.model.tree_.feature]
#
# AttributeError: 'Booster' object has no attribute 'tree_'

# %%
import xgboost as xgb
y_mean = np.mean(y_train)
xgb_params = {
    'eta' : 0.04,  # 0.037 grid search = .04
    'max_depth' : 6,  #5
    'subsample' : 0.80,
    'objective' : 'reg:linear',
    'eval_metric' : 'mae',
    'lambda' : 0.8,
    'alpha' : 0.4,
    'base_score' : y_mean,
    'silent' : 1,
    'min_child_weight': 5  # grid search
}

# %%
dtrain = xgb.DMatrix(x_train, y_train)
dtest = xgb.DMatrix(x_test)

# %%
num_boost_rounds = 250 

# training
model = xgb.train(dict(xgb_params, silent=1), dtrain, num_boost_round=num_boost_rounds)

# predict
xgb_pred1 = model.predict(dtest)
xgb_pred1
# Out:
# array([nan, nan, nan, ..., nan, nan, nan], dtype=float32)

# %%
ax = xgb.plot_importance(model)
fig = ax.figure
fig.set_size_inches(20, 20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-3633f1cccaf2> in <module>
# ----> 1 ax = xgb.plot_importance(model)
#       2 fig = ax.figure
#       3 fig.set_size_inches(20, 20)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/xgboost/plotting.py in plot_importance(booster, ax, height, xlim, ylim, title, xlabel, ylabel, importance_type, max_num_features, grid, show_values, **kwargs)
#      71
#      72     if not importance:
# ---> 73         raise ValueError('Booster.get_score() results in empty')
#      74
#      75     tuples = [(k, importance[k]) for k in importance]
#
# ValueError: Booster.get_score() results in empty
